# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../weather.csv')

# %%
x = [1,2,3,4,5,6]
y = [1,5,3,5,7,8]
plt.plot(x,y)
plt.show()

# %%
f = plt.figure()

f.set_figwidth(4)
f.set_figheight(2)
plt.plot(x,y)
plt.show()

# %%
plt.figure(figsize=(6,3))
display(plt.plot(x,y))
