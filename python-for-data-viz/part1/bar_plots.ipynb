# %%
import matplotlib.pyplot as plt
import numpy as np
import statistics

# %%
languages = ['C','C++','Java','Python','PHP']
students1 = np.random.rand(1,5)
students2 = np.random.rand(1,5)
plt.barh(languages,students1[0])
plt.bar(languages,students1[0])
plt.bar(languages,students1[0],bottom=students1[0])
plt.bar(languages,students1[0],bottom=students1[0]+students2[0])
plt.show()
