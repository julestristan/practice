# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics

# %%
blood_sample_men = [129,126,89,92,90,92,109,105,110,127,111,98,80,87]
blood_sample_women = [169,120,89,85,88,90,96,99,108,100,106,112,122,123]

plt.hist([blood_sample_men,blood_sample_women],bins = [80,100,120,140],color=['g','b'],label=['men','women'])
plt.legend()
