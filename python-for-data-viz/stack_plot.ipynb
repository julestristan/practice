# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
minutes = [0,1,2,3,4,5,6,7]
score1 = [3,5,6,6,7,8,8,9]
score2 = [0,3,4,4,5,7,9,11]
score3 = [1,2,3,3,3,4,5,9]
plt.stackplot(minutes,score1,score2,score3,labels=['Score 1','Score 2','Score 3'])
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
